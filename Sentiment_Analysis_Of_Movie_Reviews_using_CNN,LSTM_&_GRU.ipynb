# %% [markdown]
# # Sentiment Analysis Of Movie Reviews using CNN&LSTM

# %% [markdown]
# ## Using LSTMs, CNNs, GRUs with a GLUE dataset

# %% [markdown]
# In this colab, We different kinds of layers to see how they affect the model.
#
# We will use the glue/sst2 dataset, which is available through tensorflow_datasets.
#
# The General Language Understanding Evaluation (GLUE) benchmark (https://gluebenchmark.com/) is a collection of resources for training, evaluating, and analyzing natural language understanding systems.
#
# These resources include the Stanford Sentiment Treebank (SST) dataset that consists of sentences from movie reviews and human annotations of their sentiment. This colab uses version 2 of the SST dataset.
#
# The splits are:
#
# *   train	67,349
# *   validation	872
#
#
# and the column headings are:
#
# *   sentence
# *   label
#
#
# For more information about the dataset, see [https://www.tensorflow.org/datasets/catalog/glue#gluesst2](https://www.tensorflow.org/datasets/catalog/glue#gluesst2)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import numpy as np

# %% [markdown]
# # Get the dataset

# %%
# Get the dataset.
# It has 70000 items, so might take a while to download
dataset, info = tfds.load('glue/sst2', with_info=True)
print(info.features)
print(info.features["label"].num_classes)
print(info.features["label"].names)
# Out:
# Downloading and preparing dataset 7.09 MiB (download: 7.09 MiB, generated: 7.22 MiB, total: 14.31 MiB) to /root/tensorflow_datasets/glue/sst2/2.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/2.0.0.incompleteA8O6RA/glue-train.tfrecord*...:   0%|          |…
# Generating validation examples...:   0%|          | 0/872 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/2.0.0.incompleteA8O6RA/glue-validation.tfrecord*...:   0%|      …
# Generating test examples...:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/glue/sst2/2.0.0.incompleteA8O6RA/glue-test.tfrecord*...:   0%|          | …
# Dataset glue downloaded and prepared to /root/tensorflow_datasets/glue/sst2/2.0.0. Subsequent calls will reuse this data.
# FeaturesDict({
#     'idx': int32,
#     'label': ClassLabel(shape=(), dtype=int64, num_classes=2),
#     'sentence': Text(shape=(), dtype=string),
# })
# 2
# ['negative', 'positive']

# %%
# Get the training and validation datasets
dataset_train, dataset_validation = dataset['train'], dataset['validation']
dataset_train
# Out:
# <_PrefetchDataset element_spec={'idx': TensorSpec(shape=(), dtype=tf.int32, name=None), 'label': TensorSpec(shape=(), dtype=tf.int64, name=None), 'sentence': TensorSpec(shape=(), dtype=tf.string, name=None)}>

# %%
# Print some of the entries
for example in dataset_train.take(2):  
  review, label = example["sentence"], example["label"]
  print("Review:", review)
  print("Label: %d \n" % label.numpy())
# Out:
# Review: tf.Tensor(b'for the uninitiated plays better on video with the sound ', shape=(), dtype=string)
# Label: 0
#
# Review: tf.Tensor(b'like a giant commercial for universal studios , where much of the action takes place ', shape=(), dtype=string)
# Label: 0

# %%
# Get the sentences and the labels
# for both the training and the validation sets
training_reviews = []
training_labels = []
 
validation_reviews = []
validation_labels = []

# The dataset has 67,000 training entries, but that's a lot to process here!

# Take 8,000 reviews
for item in dataset_train.take(8000):
  review, label = item["sentence"], item["label"]
  training_reviews.append(str(review.numpy()))
  training_labels.append(label.numpy())

print ("\nNumber of training reviews is: ", len(training_reviews))

# print some of the reviews and labels
for i in range(0, 2):
  print (training_reviews[i])
  print (training_labels[i])

# Get the validation data
# there's only about 800 items, so take them all
for item in dataset_validation.take(-1):  
  review, label = item["sentence"], item["label"]
  validation_reviews.append(str(review.numpy()))
  validation_labels.append(label.numpy())

print ("\nNumber of validation reviews is: ", len(validation_reviews))

# Print some of the validation reviews and labels
for i in range(0, 2):
  print (validation_reviews[i])
  print (validation_labels[i])
# Out:
# Number of training reviews is:  8000
# b'for the uninitiated plays better on video with the sound '
# 0
# b'like a giant commercial for universal studios , where much of the action takes place '
# 0
#
# Number of validation reviews is:  872
# b'a valueless kiddie paean to pro basketball underwritten by the nba . '
# 0
# b"featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results . "
# 1

# %% [markdown]
# # Tokenize the words and sequence the sentences

# %%
# There's a total of 21224 words in the reviews
# but many of them are irrelevant like with, it, of, on.
# If we take a subset of the training data, then the vocab
# will be smaller.

# A reasonable review might have about 50 words or so,
# so we can set max_length to 50 

vocab_size = 4000
embedding_dim = 16
max_length = 50
trunc_type='post'
pad_type='post'
oov_tok = "<OOV>"

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_reviews)
word_index = tokenizer.word_index

# %% [markdown]
# # Pad the sequences

# %%
# Pad the sequences so that they are all the same length
training_sequences = tokenizer.texts_to_sequences(training_reviews)
training_padded = pad_sequences(training_sequences,maxlen=max_length, 
                                truncating=trunc_type, padding=pad_type)

validation_sequences = tokenizer.texts_to_sequences(validation_reviews)
validation_padded = pad_sequences(validation_sequences,maxlen=max_length)

training_labels_final = np.array(training_labels)
validation_labels_final = np.array(validation_labels)

# %% [markdown]
# # Create the model using an Embedding

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),  
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 16)            64000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 64,017
# Trainable params: 64,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the model

# %%
num_epochs = 20
history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_labels_final))
# Out:
# Epoch 1/20
# 250/250 [==============================] - 23s 72ms/step - loss: 0.6842 - accuracy: 0.5608 - val_loss: 0.6917 - val_accuracy: 0.5115
# Epoch 2/20
# 250/250 [==============================] - 5s 17ms/step - loss: 0.6751 - accuracy: 0.5679 - val_loss: 0.6787 - val_accuracy: 0.5791
# Epoch 3/20
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6599 - accuracy: 0.6026 - val_loss: 0.6603 - val_accuracy: 0.6261
# Epoch 4/20
# 250/250 [==============================] - 2s 6ms/step - loss: 0.6367 - accuracy: 0.6530 - val_loss: 0.6369 - val_accuracy: 0.6445
# Epoch 5/20
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6091 - accuracy: 0.6850 - val_loss: 0.6113 - val_accuracy: 0.6904
# Epoch 6/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.5801 - accuracy: 0.7193 - val_loss: 0.5870 - val_accuracy: 0.7076
# Epoch 7/20
# 250/250 [==============================] - 2s 7ms/step - loss: 0.5511 - accuracy: 0.7420 - val_loss: 0.5669 - val_accuracy: 0.7362
# Epoch 8/20
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5247 - accuracy: 0.7664 - val_loss: 0.5499 - val_accuracy: 0.7443
# Epoch 9/20
# 250/250 [==============================] - 1s 6ms/step - loss: 0.4992 - accuracy: 0.7872 - val_loss: 0.5329 - val_accuracy: 0.7500
# Epoch 10/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4761 - accuracy: 0.8044 - val_loss: 0.5205 - val_accuracy: 0.7615
# Epoch 11/20
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4555 - accuracy: 0.8164 - val_loss: 0.5116 - val_accuracy: 0.7615
# Epoch 12/20
# 250/250 [==============================] - 2s 6ms/step - loss: 0.4355 - accuracy: 0.8226 - val_loss: 0.5050 - val_accuracy: 0.7718
# Epoch 13/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4186 - accuracy: 0.8335 - val_loss: 0.4995 - val_accuracy: 0.7683
# Epoch 14/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4020 - accuracy: 0.8389 - val_loss: 0.4968 - val_accuracy: 0.7729
# Epoch 15/20
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3871 - accuracy: 0.8474 - val_loss: 0.4969 - val_accuracy: 0.7729
# Epoch 16/20
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3739 - accuracy: 0.8490 - val_loss: 0.4985 - val_accuracy: 0.7603
# Epoch 17/20
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3615 - accuracy: 0.8534 - val_loss: 0.4960 - val_accuracy: 0.7764
# Epoch 18/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3503 - accuracy: 0.8574 - val_loss: 0.4979 - val_accuracy: 0.7752
# Epoch 19/20
# 250/250 [==============================] - 2s 6ms/step - loss: 0.3392 - accuracy: 0.8612 - val_loss: 0.5001 - val_accuracy: 0.7764
# Epoch 20/20
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3296 - accuracy: 0.8650 - val_loss: 0.5081 - val_accuracy: 0.7603

# %% [markdown]
# # Plot the accurracy and loss

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %% [markdown]
# # Write a function to predict the sentiment of reviews

# %%
# Write some new reviews 

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

new_reviews = [review1, review2, review3, review4]

# %%
# Define a function to prepare the new reviews for use with a model
# and then use the model to predict the sentiment of the new reviews           

def predict_review(model, reviews):
  # Create the sequences
  padding_type='post'
  sample_sequences = tokenizer.texts_to_sequences(reviews)
  reviews_padded = pad_sequences(sample_sequences, padding=padding_type, 
                                 maxlen=max_length) 
  classes = model.predict(reviews_padded)
  for x in range(len(reviews_padded)):
    print(reviews[x])
    print(classes[x])
    print('\n')

predict_review(model, new_reviews)
# Out:
# 1/1 [==============================] - 0s 69ms/step
# I loved this movie
# [0.5032393]
#
#
# that was the worst movie I've ever seen
# [0.15083027]
#
#
# too much violence even for a Bond film
# [0.05236782]
#
#
# a captivating recounting of a cherished myth
# [0.61718583]

# %% [markdown]
# # Define a function to train and show the results of models with different layers

# %%
def fit_model_and_show_results (model, reviews):
  model.summary()
  history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                      validation_data=(validation_padded, validation_labels_final))
  plot_graphs(history, "accuracy")
  plot_graphs(history, "loss")
  predict_review(model, reviews)

# %% [markdown]
# # Use a CNN

# %%
num_epochs = 30

model_cnn = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(16, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Default learning rate for the Adam optimizer is 0.001
# Let's slow down the learning rate by 10.
learning_rate = 0.0001
model_cnn.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate), 
                  metrics=['accuracy'])

fit_model_and_show_results(model_cnn, new_reviews)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 50, 16)            64000
#
#  conv1d (Conv1D)             (None, 46, 16)            1296
#
#  global_max_pooling1d (Globa  (None, 16)               0
#  lMaxPooling1D)
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 65,313
# Trainable params: 65,313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 250/250 [==============================] - 20s 56ms/step - loss: 0.6908 - accuracy: 0.5441 - val_loss: 0.6925 - val_accuracy: 0.5287
# Epoch 2/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.6837 - accuracy: 0.5725 - val_loss: 0.6915 - val_accuracy: 0.5103
# Epoch 3/30
# 250/250 [==============================] - 2s 6ms/step - loss: 0.6785 - accuracy: 0.5635 - val_loss: 0.6901 - val_accuracy: 0.5115
# Epoch 4/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.6731 - accuracy: 0.5670 - val_loss: 0.6876 - val_accuracy: 0.5149
# Epoch 5/30
# 250/250 [==============================] - 1s 6ms/step - loss: 0.6664 - accuracy: 0.5809 - val_loss: 0.6834 - val_accuracy: 0.5883
# Epoch 6/30
# 250/250 [==============================] - 2s 6ms/step - loss: 0.6575 - accuracy: 0.6154 - val_loss: 0.6772 - val_accuracy: 0.6445
# Epoch 7/30
# 250/250 [==============================] - 1s 6ms/step - loss: 0.6454 - accuracy: 0.6507 - val_loss: 0.6690 - val_accuracy: 0.6858
# Epoch 8/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.6296 - accuracy: 0.7009 - val_loss: 0.6586 - val_accuracy: 0.7041
# Epoch 9/30
# 250/250 [==============================] - 2s 6ms/step - loss: 0.6098 - accuracy: 0.7334 - val_loss: 0.6467 - val_accuracy: 0.7064
# Epoch 10/30
# 250/250 [==============================] - 2s 6ms/step - loss: 0.5863 - accuracy: 0.7670 - val_loss: 0.6330 - val_accuracy: 0.7179
# Epoch 11/30
# 250/250 [==============================] - 1s 6ms/step - loss: 0.5597 - accuracy: 0.7851 - val_loss: 0.6186 - val_accuracy: 0.7167
# Epoch 12/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5315 - accuracy: 0.8024 - val_loss: 0.6053 - val_accuracy: 0.7167
# Epoch 13/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.5031 - accuracy: 0.8120 - val_loss: 0.5933 - val_accuracy: 0.7156
# Epoch 14/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4758 - accuracy: 0.8246 - val_loss: 0.5815 - val_accuracy: 0.7259
# Epoch 15/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4497 - accuracy: 0.8341 - val_loss: 0.5682 - val_accuracy: 0.7282
# Epoch 16/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.4257 - accuracy: 0.8400 - val_loss: 0.5537 - val_accuracy: 0.7431
# Epoch 17/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.4040 - accuracy: 0.8490 - val_loss: 0.5499 - val_accuracy: 0.7385
# Epoch 18/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3842 - accuracy: 0.8553 - val_loss: 0.5409 - val_accuracy: 0.7466
# Epoch 19/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3664 - accuracy: 0.8609 - val_loss: 0.5345 - val_accuracy: 0.7511
# Epoch 20/30
# 250/250 [==============================] - 1s 5ms/step - loss: 0.3502 - accuracy: 0.8646 - val_loss: 0.5258 - val_accuracy: 0.7615
# Epoch 21/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.3354 - accuracy: 0.8685 - val_loss: 0.5201 - val_accuracy: 0.7683
# Epoch 22/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3218 - accuracy: 0.8720 - val_loss: 0.5190 - val_accuracy: 0.7638
# Epoch 23/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3093 - accuracy: 0.8764 - val_loss: 0.5130 - val_accuracy: 0.7638
# Epoch 24/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2979 - accuracy: 0.8798 - val_loss: 0.5130 - val_accuracy: 0.7580
# Epoch 25/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2871 - accuracy: 0.8840 - val_loss: 0.5142 - val_accuracy: 0.7534
# Epoch 26/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2773 - accuracy: 0.8884 - val_loss: 0.5125 - val_accuracy: 0.7569
# Epoch 27/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2680 - accuracy: 0.8925 - val_loss: 0.5117 - val_accuracy: 0.7603
# Epoch 28/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2590 - accuracy: 0.8965 - val_loss: 0.5104 - val_accuracy: 0.7729
# Epoch 29/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2511 - accuracy: 0.8995 - val_loss: 0.5145 - val_accuracy: 0.7718
# Epoch 30/30
# 250/250 [==============================] - 1s 4ms/step - loss: 0.2433 - accuracy: 0.9031 - val_loss: 0.5157 - val_accuracy: 0.7752
# 1/1 [==============================] - 0s 80ms/step
# I loved this movie
# [0.933182]
#
#
# that was the worst movie I've ever seen
# [0.04147234]
#
#
# too much violence even for a Bond film
# [0.00768872]
#
#
# a captivating recounting of a cherished myth
# [0.6983186]

# %% [markdown]
# # Use a GRU

# %%
num_epochs = 30

model_gru = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
model_gru.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=['accuracy'])

fit_model_and_show_results(model_gru, new_reviews)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional (Bidirectiona  (None, 64)               9600
#  l)
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 73,665
# Trainable params: 73,665
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 250/250 [==============================] - 21s 65ms/step - loss: 0.6906 - accuracy: 0.5554 - val_loss: 0.6930 - val_accuracy: 0.5092
# Epoch 2/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.6872 - accuracy: 0.5606 - val_loss: 0.6936 - val_accuracy: 0.5092
# Epoch 3/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.6852 - accuracy: 0.5606 - val_loss: 0.6946 - val_accuracy: 0.5092
# Epoch 4/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.6838 - accuracy: 0.5606 - val_loss: 0.6955 - val_accuracy: 0.5092
# Epoch 5/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.6824 - accuracy: 0.5606 - val_loss: 0.6965 - val_accuracy: 0.5092
# Epoch 6/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6806 - accuracy: 0.5606 - val_loss: 0.6972 - val_accuracy: 0.5092
# Epoch 7/30
# 250/250 [==============================] - 3s 10ms/step - loss: 0.6780 - accuracy: 0.5606 - val_loss: 0.6986 - val_accuracy: 0.5092
# Epoch 8/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.6742 - accuracy: 0.5606 - val_loss: 0.7006 - val_accuracy: 0.5092
# Epoch 9/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.6686 - accuracy: 0.5614 - val_loss: 0.7052 - val_accuracy: 0.5092
# Epoch 10/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6599 - accuracy: 0.5710 - val_loss: 0.7119 - val_accuracy: 0.5092
# Epoch 11/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6470 - accuracy: 0.6145 - val_loss: 0.7239 - val_accuracy: 0.5092
# Epoch 12/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.6290 - accuracy: 0.6445 - val_loss: 0.7152 - val_accuracy: 0.5092
# Epoch 13/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.6021 - accuracy: 0.6694 - val_loss: 0.6719 - val_accuracy: 0.5138
# Epoch 14/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5694 - accuracy: 0.6988 - val_loss: 0.6436 - val_accuracy: 0.5413
# Epoch 15/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5478 - accuracy: 0.7184 - val_loss: 0.6303 - val_accuracy: 0.5986
# Epoch 16/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.5312 - accuracy: 0.7326 - val_loss: 0.6221 - val_accuracy: 0.6433
# Epoch 17/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5158 - accuracy: 0.7495 - val_loss: 0.6214 - val_accuracy: 0.6835
# Epoch 18/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.5014 - accuracy: 0.7615 - val_loss: 0.6210 - val_accuracy: 0.7041
# Epoch 19/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.4872 - accuracy: 0.7736 - val_loss: 0.6268 - val_accuracy: 0.7122
# Epoch 20/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.4735 - accuracy: 0.7841 - val_loss: 0.6321 - val_accuracy: 0.7213
# Epoch 21/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.4625 - accuracy: 0.7899 - val_loss: 0.6158 - val_accuracy: 0.7294
# Epoch 22/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.4475 - accuracy: 0.7961 - val_loss: 0.6112 - val_accuracy: 0.7282
# Epoch 23/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.4360 - accuracy: 0.8015 - val_loss: 0.6210 - val_accuracy: 0.7374
# Epoch 24/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.4253 - accuracy: 0.8090 - val_loss: 0.6144 - val_accuracy: 0.7385
# Epoch 25/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.4141 - accuracy: 0.8191 - val_loss: 0.6194 - val_accuracy: 0.7443
# Epoch 26/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.4034 - accuracy: 0.8240 - val_loss: 0.6166 - val_accuracy: 0.7523
# Epoch 27/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3962 - accuracy: 0.8254 - val_loss: 0.6081 - val_accuracy: 0.7546
# Epoch 28/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.3856 - accuracy: 0.8309 - val_loss: 0.5973 - val_accuracy: 0.7569
# Epoch 29/30
# 250/250 [==============================] - 2s 7ms/step - loss: 0.3799 - accuracy: 0.8355 - val_loss: 0.6024 - val_accuracy: 0.7649
# Epoch 30/30
# 250/250 [==============================] - 2s 10ms/step - loss: 0.3721 - accuracy: 0.8438 - val_loss: 0.6032 - val_accuracy: 0.7661
# 1/1 [==============================] - 1s 680ms/step
# I loved this movie
# [0.4125788]
#
#
# that was the worst movie I've ever seen
# [0.19913635]
#
#
# too much violence even for a Bond film
# [0.26374146]
#
#
# a captivating recounting of a cherished myth
# [0.39554447]

# %% [markdown]
# # Add a bidirectional LSTM

# %%
num_epochs = 30

model_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)), 
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003
model_bidi_lstm.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(learning_rate),
                        metrics=['accuracy'])
fit_model_and_show_results(model_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_1 (Bidirectio  (None, 32)               4224
#  nal)
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 68,257
# Trainable params: 68,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 250/250 [==============================] - 19s 61ms/step - loss: 0.6899 - accuracy: 0.5606 - val_loss: 0.6932 - val_accuracy: 0.5092
# Epoch 2/30
# 250/250 [==============================] - 5s 19ms/step - loss: 0.6872 - accuracy: 0.5606 - val_loss: 0.6938 - val_accuracy: 0.5092
# Epoch 3/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.6854 - accuracy: 0.5606 - val_loss: 0.6946 - val_accuracy: 0.5092
# Epoch 4/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6845 - accuracy: 0.5606 - val_loss: 0.6956 - val_accuracy: 0.5092
# Epoch 5/30
# 250/250 [==============================] - 3s 10ms/step - loss: 0.6838 - accuracy: 0.5606 - val_loss: 0.6961 - val_accuracy: 0.5092
# Epoch 6/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6830 - accuracy: 0.5606 - val_loss: 0.6968 - val_accuracy: 0.5092
# Epoch 7/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6822 - accuracy: 0.5606 - val_loss: 0.6975 - val_accuracy: 0.5092
# Epoch 8/30
# 250/250 [==============================] - 3s 14ms/step - loss: 0.6812 - accuracy: 0.5606 - val_loss: 0.6982 - val_accuracy: 0.5092
# Epoch 9/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6800 - accuracy: 0.5606 - val_loss: 0.6986 - val_accuracy: 0.5092
# Epoch 10/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6785 - accuracy: 0.5606 - val_loss: 0.6997 - val_accuracy: 0.5092
# Epoch 11/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6768 - accuracy: 0.5606 - val_loss: 0.7013 - val_accuracy: 0.5092
# Epoch 12/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6747 - accuracy: 0.5608 - val_loss: 0.7020 - val_accuracy: 0.5092
# Epoch 13/30
# 250/250 [==============================] - 3s 10ms/step - loss: 0.6724 - accuracy: 0.5608 - val_loss: 0.7029 - val_accuracy: 0.5092
# Epoch 14/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6697 - accuracy: 0.5625 - val_loss: 0.7036 - val_accuracy: 0.5092
# Epoch 15/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6667 - accuracy: 0.5671 - val_loss: 0.7052 - val_accuracy: 0.5092
# Epoch 16/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.6632 - accuracy: 0.5740 - val_loss: 0.7030 - val_accuracy: 0.5092
# Epoch 17/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6592 - accuracy: 0.5878 - val_loss: 0.7051 - val_accuracy: 0.5092
# Epoch 18/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.6547 - accuracy: 0.5929 - val_loss: 0.7025 - val_accuracy: 0.5080
# Epoch 19/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6496 - accuracy: 0.6077 - val_loss: 0.7035 - val_accuracy: 0.5080
# Epoch 20/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6436 - accuracy: 0.6150 - val_loss: 0.7007 - val_accuracy: 0.5092
# Epoch 21/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6365 - accuracy: 0.6226 - val_loss: 0.6937 - val_accuracy: 0.5115
# Epoch 22/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6282 - accuracy: 0.6349 - val_loss: 0.6869 - val_accuracy: 0.5149
# Epoch 23/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.6186 - accuracy: 0.6445 - val_loss: 0.6752 - val_accuracy: 0.5195
# Epoch 24/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.6073 - accuracy: 0.6545 - val_loss: 0.6580 - val_accuracy: 0.5367
# Epoch 25/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5943 - accuracy: 0.6695 - val_loss: 0.6373 - val_accuracy: 0.5952
# Epoch 26/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5798 - accuracy: 0.6930 - val_loss: 0.6124 - val_accuracy: 0.6491
# Epoch 27/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5660 - accuracy: 0.7095 - val_loss: 0.5954 - val_accuracy: 0.6915
# Epoch 28/30
# 250/250 [==============================] - 2s 8ms/step - loss: 0.5532 - accuracy: 0.7291 - val_loss: 0.5800 - val_accuracy: 0.6984
# Epoch 29/30
# 250/250 [==============================] - 2s 9ms/step - loss: 0.5431 - accuracy: 0.7439 - val_loss: 0.5696 - val_accuracy: 0.7064
# Epoch 30/30
# 250/250 [==============================] - 3s 11ms/step - loss: 0.5330 - accuracy: 0.7466 - val_loss: 0.5642 - val_accuracy: 0.7053
# 1/1 [==============================] - 1s 646ms/step
# I loved this movie
# [0.44073144]
#
#
# that was the worst movie I've ever seen
# [0.3606167]
#
#
# too much violence even for a Bond film
# [0.46310478]
#
#
# a captivating recounting of a cherished myth
# [0.47494856]

# %% [markdown]
# # Use multiple bidirectional LSTMs

# %%
num_epochs = 30

model_multiple_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, 
                                                       return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.0003
model_multiple_bidi_lstm.compile(loss='binary_crossentropy',
                                 optimizer=tf.keras.optimizers.Adam(learning_rate),
                                 metrics=['accuracy'])
fit_model_and_show_results(model_multiple_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 16)            64000
#
#  bidirectional_2 (Bidirectio  (None, 50, 32)           4224
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 32)               6272
#  nal)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 74,529
# Trainable params: 74,529
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 250/250 [==============================] - 25s 75ms/step - loss: 0.6843 - accuracy: 0.5537 - val_loss: 0.7100 - val_accuracy: 0.5092
# Epoch 2/30
# 250/250 [==============================] - 6s 23ms/step - loss: 0.5684 - accuracy: 0.6938 - val_loss: 0.7532 - val_accuracy: 0.5229
# Epoch 3/30
# 250/250 [==============================] - 5s 20ms/step - loss: 0.3850 - accuracy: 0.8230 - val_loss: 0.7768 - val_accuracy: 0.5241
# Epoch 4/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.3071 - accuracy: 0.8636 - val_loss: 0.7797 - val_accuracy: 0.4071
# Epoch 5/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.2576 - accuracy: 0.8836 - val_loss: 0.8599 - val_accuracy: 0.3360
# Epoch 6/30
# 250/250 [==============================] - 4s 17ms/step - loss: 0.2318 - accuracy: 0.8971 - val_loss: 0.8896 - val_accuracy: 0.4633
# Epoch 7/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.2114 - accuracy: 0.9049 - val_loss: 0.9082 - val_accuracy: 0.4323
# Epoch 8/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1951 - accuracy: 0.9149 - val_loss: 1.2652 - val_accuracy: 0.3498
# Epoch 9/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1810 - accuracy: 0.9172 - val_loss: 1.3958 - val_accuracy: 0.2901
# Epoch 10/30
# 250/250 [==============================] - 4s 17ms/step - loss: 0.1664 - accuracy: 0.9247 - val_loss: 1.3572 - val_accuracy: 0.4163
# Epoch 11/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1576 - accuracy: 0.9280 - val_loss: 1.4000 - val_accuracy: 0.3784
# Epoch 12/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1518 - accuracy: 0.9302 - val_loss: 1.5438 - val_accuracy: 0.3578
# Epoch 13/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1475 - accuracy: 0.9314 - val_loss: 1.4761 - val_accuracy: 0.3635
# Epoch 14/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1423 - accuracy: 0.9376 - val_loss: 1.8806 - val_accuracy: 0.3670
# Epoch 15/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1408 - accuracy: 0.9350 - val_loss: 1.6950 - val_accuracy: 0.3865
# Epoch 16/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1352 - accuracy: 0.9379 - val_loss: 1.4461 - val_accuracy: 0.3693
# Epoch 17/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1319 - accuracy: 0.9373 - val_loss: 1.8721 - val_accuracy: 0.3635
# Epoch 18/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1257 - accuracy: 0.9384 - val_loss: 1.9772 - val_accuracy: 0.3842
# Epoch 19/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1263 - accuracy: 0.9395 - val_loss: 1.8083 - val_accuracy: 0.3888
# Epoch 20/30
# 250/250 [==============================] - 3s 14ms/step - loss: 0.1230 - accuracy: 0.9395 - val_loss: 1.9551 - val_accuracy: 0.3968
# Epoch 21/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1213 - accuracy: 0.9375 - val_loss: 2.2021 - val_accuracy: 0.3647
# Epoch 22/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1228 - accuracy: 0.9351 - val_loss: 2.0404 - val_accuracy: 0.3830
# Epoch 23/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1214 - accuracy: 0.9384 - val_loss: 2.0072 - val_accuracy: 0.4014
# Epoch 24/30
# 250/250 [==============================] - 4s 16ms/step - loss: 0.1189 - accuracy: 0.9410 - val_loss: 1.9907 - val_accuracy: 0.3601
# Epoch 25/30
# 250/250 [==============================] - 3s 13ms/step - loss: 0.1105 - accuracy: 0.9416 - val_loss: 1.9452 - val_accuracy: 0.3888
# Epoch 26/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1117 - accuracy: 0.9435 - val_loss: 2.0989 - val_accuracy: 0.3922
# Epoch 27/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1043 - accuracy: 0.9444 - val_loss: 1.9908 - val_accuracy: 0.3956
# Epoch 28/30
# 250/250 [==============================] - 4s 15ms/step - loss: 0.1039 - accuracy: 0.9436 - val_loss: 2.1487 - val_accuracy: 0.3991
# Epoch 29/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1096 - accuracy: 0.9398 - val_loss: 1.9574 - val_accuracy: 0.4335
# Epoch 30/30
# 250/250 [==============================] - 3s 12ms/step - loss: 0.1035 - accuracy: 0.9439 - val_loss: 2.3169 - val_accuracy: 0.4128
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f5a41554700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# I loved this movie
# [0.9940706]
#
#
# that was the worst movie I've ever seen
# [0.08078956]
#
#
# too much violence even for a Bond film
# [0.00322508]
#
#
# a captivating recounting of a cherished myth
# [0.99757916]

# %% [markdown]
# # Try some more reviews

# %%
# Write some new reviews 

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

review5 = """I saw this movie yesterday and I was feeling low to start with,
 but it was such a wonderful movie that it lifted my spirits and brightened 
 my day, you can\'t go wrong with a movie with Whoopi Goldberg in it."""

review6 = """I don\'t understand why it received an oscar recommendation
 for best movie, it was long and boring"""

review7 = """the scenery was magnificent, the CGI of the dogs was so realistic I
 thought they were played by real dogs even though they talked!"""

review8 = """The ending was so sad and yet so uplifting at the same time. 
 I'm looking for an excuse to see it again"""

review9 = """I had expected so much more from a movie made by the director 
 who made my most favorite movie ever, I was very disappointed in the tedious 
 story"""

review10 = "I wish I could watch this movie every day for the rest of my life"

more_reviews = [review1, review2, review3, review4, review5, review6, review7, 
               review8, review9, review10]

# %%
print("============================\n","Embeddings only:\n", "============================")
predict_review(model, more_reviews)
# Out:
# ============================
#  Embeddings only:
#  ============================
# 1/1 [==============================] - 0s 18ms/step
# I loved this movie
# [0.5032393]
#
#
# that was the worst movie I've ever seen
# [0.15083027]
#
#
# too much violence even for a Bond film
# [0.05236782]
#
#
# a captivating recounting of a cherished myth
# [0.61718583]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.45279458]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.54745144]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.20134313]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.3587507]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.0080603]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.5234008]

# %%
print("============================\n","With CNN\n", "============================")
predict_review(model_cnn, more_reviews)
# Out:
# ============================
#  With CNN
#  ============================
# 1/1 [==============================] - 0s 33ms/step
# I loved this movie
# [0.933182]
#
#
# that was the worst movie I've ever seen
# [0.04147234]
#
#
# too much violence even for a Bond film
# [0.00768872]
#
#
# a captivating recounting of a cherished myth
# [0.6983186]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.40168023]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.629494]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.14655204]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.45722103]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.04033475]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.7704765]

# %%
print("===========================\n","With bidirectional GRU\n", "============================")
predict_review(model_gru, more_reviews)
# Out:
# ===========================
#  With bidirectional GRU
#  ============================
# 1/1 [==============================] - 0s 20ms/step
# I loved this movie
# [0.4125788]
#
#
# that was the worst movie I've ever seen
# [0.19913635]
#
#
# too much violence even for a Bond film
# [0.26374146]
#
#
# a captivating recounting of a cherished myth
# [0.39554447]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.07777981]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.18763487]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.11239766]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.25076482]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.04847324]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.3014487]

# %%
print("===========================\n", "With a single bidirectional LSTM:\n", "===========================")
predict_review(model_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With a single bidirectional LSTM:
#  ===========================
# 1/1 [==============================] - 0s 21ms/step
# I loved this movie
# [0.44073144]
#
#
# that was the worst movie I've ever seen
# [0.3606167]
#
#
# too much violence even for a Bond film
# [0.46310478]
#
#
# a captivating recounting of a cherished myth
# [0.47494856]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.27636933]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.32515278]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.3156948]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.3807244]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.22223553]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.445546]

# %%
print("===========================\n", "With multiple bidirectional LSTM:\n", "==========================")
predict_review(model_multiple_bidi_lstm, more_reviews)
# Out:
# ===========================
#  With multiple bidirectional LSTM:
#  ==========================
# 1/1 [==============================] - 0s 22ms/step
# I loved this movie
# [0.9940706]
#
#
# that was the worst movie I've ever seen
# [0.08078956]
#
#
# too much violence even for a Bond film
# [0.00322508]
#
#
# a captivating recounting of a cherished myth
# [0.99757916]
#
#
# I saw this movie yesterday and I was feeling low to start with,
#  but it was such a wonderful movie that it lifted my spirits and brightened
#  my day, you can't go wrong with a movie with Whoopi Goldberg in it.
# [0.9990876]
#
#
# I don't understand why it received an oscar recommendation
#  for best movie, it was long and boring
# [0.9992003]
#
#
# the scenery was magnificent, the CGI of the dogs was so realistic I
#  thought they were played by real dogs even though they talked!
# [0.96162105]
#
#
# The ending was so sad and yet so uplifting at the same time.
#  I'm looking for an excuse to see it again
# [0.9993223]
#
#
# I had expected so much more from a movie made by the director
#  who made my most favorite movie ever, I was very disappointed in the tedious
#  story
# [0.00411833]
#
#
# I wish I could watch this movie every day for the rest of my life
# [0.07331023]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# An important item to note here is these performance differences (with perhaps the exception of training duration) will vary depending on the dataset and other changes to the model - you shouldn’t always assume one type of model will work better than another.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
